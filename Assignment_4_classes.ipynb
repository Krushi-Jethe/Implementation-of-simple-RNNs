# %% [markdown]
# #  RNNs

# %% [markdown]
# #### GRU , LSTM , SIMPLE_RNN FOR CHARACTER LEVEL PREDICTION
# #### BI-DIRECTIONAL LSTM FOR WORD LEVEL PREDICTION

# %% [markdown]
# ## 1. IMPORTING LIBRARIES
#
# #### my_rnns has implementations of custom classes

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import time
import numpy as np
from my_rnns import process_data,data_set,initializers,GRU_Model,LSTM_Model,RNN_Model,OneStep

# %% [markdown]
# ## 2. FUNCTION TO RETRIEVE TEXT FILE

# %%
def get_txt_file(name,url):
        path_to_file = tf.keras.utils.get_file(name , url)
        text = open(path_to_file, 'rb').read().decode(encoding='utf-8')
        print(f'Length of text: {len(text)} characters')
        return text

text = get_txt_file('shakespeare.txt','https://cs.stanford.edu/people/karpathy/char-rnn/shakespeare_input.txt')
# Out:
# Length of text: 4573338 characters

# %% [markdown]
# ## 3. FUNCTION TO PLOT GRAPHS FOR CHAR LEVEL PREDICTION

# %%
def plot(model_name):
    plt.figure(figsize=(10,5))

    plt.subplot(1,2,1)
    plt.title('Accuracy vs Epochs')
    plt.plot(model_name.history['accuracy'], label='accuracy')
    plt.plot(model_name.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    plt.subplot(1,2,2)
    plt.title('Loss vs Epochs')
    plt.plot(model_name.history['loss'], label='loss')
    plt.plot(model_name.history['val_loss'], label = 'val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')

    plt.show()

# %% [markdown]
# ## 4. TOKENIZATION OF CHARACTERS

# %%
process_data_obj = process_data(text)
uniq_char = process_data_obj.get_uniq_char()
tokenizer = process_data_obj.tokenize()
chars_from_id = process_data_obj.char_from_ids()
text_from_ids = process_data_obj.text_from_ids(tokenizer(list(text[6000:6200])))
print(f'{len(uniq_char)} unique characters')
print('\n Tokenized data............\n')
print(tokenizer(list(text[6000:6200])))
print('\n Text data............\n')
print(text_from_ids)
my_string = text_from_ids.numpy().decode("utf-8")
print('\n',my_string,'\n')
# Out:
# 67 unique characters
#
#  Tokenized data............
#
# tf.Tensor(
# [46 42 59 61  7  2 61 56  2 61 49 46  2 60 46 42 61  2 56  6  2 61 49 46
#   2 43 59 42 50 55 12  1 14 55 45  7  2 61 49 59 56 62 48 49  2 61 49 46
#   2 44 59 42 55 52 60  2 42 55 45  2 56 47 47 50 44 46 60  2 56 47  2 54
#  42 55  7  1 33 49 46  2 60 61 59 56 55 48 46 60 61  2 55 46 59 63 46 60
#   2 42 55 45  2 60 54 42 53 53  2 50 55 47 46 59 50 56 59  2 63 46 50 55
#  60  1 19 59 56 54  2 54 46  2 59 46 44 46 50 63 46  2 61 49 42 61  2 55
#  42 61 62 59 42 53  2 44 56 54 57 46 61 46 55 44 66  1 36 49 46 59 46 43
#  66  2 61 49 46 66  2 53 50 63 46 11  2 42 55 45  2 61 49 56 62 48 49  2
#  61 49 42 61  2 42 53 53], shape=(200,), dtype=int64)
#
#  Text data............
#
# tf.Tensor(b"eart, to the seat o' the brain;\nAnd, through the cranks and offices of man,\nThe strongest nerves and small inferior veins\nFrom me receive that natural competency\nWhereby they live: and though that all", shape=(), dtype=string)
#
#  eart, to the seat o' the brain;
# And, through the cranks and offices of man,
# The strongest nerves and small inferior veins
# From me receive that natural competency
# Whereby they live: and though that all

# %% [markdown]
# ## 5. DATASET PREPARATION

# %%
my_data=data_set(text,100,64,0.8)
train_dataset,val_dataset = my_data.prepare(tokenizer)

# %% [markdown]
# ## 6. GRU , LSTM , SIMPLE-RNN FOR CHAR LEVEL PREDICTION

# %%
gru_model = GRU_Model(len(tokenizer.get_vocabulary()))
lstm_model = LSTM_Model(len(tokenizer.get_vocabulary()))
rnn_model = RNN_Model(len(tokenizer.get_vocabulary()))

# %%
gru_model.compile(optimizer=gru_model.optimizer, loss=gru_model.loss,metrics=gru_model.metric)
gru_model.fit(train_dataset, epochs=gru_model.epochs, validation_data=val_dataset, callbacks=gru_model.callbacks)
gru_history = gru_model.history
plot(gru_history)
# Out:
# Epoch 1/30
# 565/565 [==============================] - 25s 36ms/step - loss: 2.1449 - accuracy: 0.3938 - val_loss: 1.6516 - val_accuracy: 0.5075 - lr: 0.0010
# Epoch 2/30
# 565/565 [==============================] - 21s 36ms/step - loss: 1.5168 - accuracy: 0.5424 - val_loss: 1.4187 - val_accuracy: 0.5691 - lr: 0.0010
# Epoch 3/30
# 565/565 [==============================] - 21s 36ms/step - loss: 1.3760 - accuracy: 0.5779 - val_loss: 1.3405 - val_accuracy: 0.5864 - lr: 0.0010
# Epoch 4/30
# 565/565 [==============================] - 21s 36ms/step - loss: 1.3134 - accuracy: 0.5931 - val_loss: 1.2903 - val_accuracy: 0.6008 - lr: 0.0010
# Epoch 5/30
# 565/565 [==============================] - 21s 36ms/step - loss: 1.2738 - accuracy: 0.6031 - val_loss: 1.2549 - val_accuracy: 0.6094 - lr: 0.0010
# Epoch 6/30
# 565/565 [==============================] - 21s 36ms/step - loss: 1.2423 - accuracy: 0.6113 - val_loss: 1.2283 - val_accuracy: 0.6163 - lr: 0.0010
# Epoch 7/30
# 565/565 [==============================] - 21s 36ms/step - loss: 1.2152 - accuracy: 0.6185 - val_loss: 1.2086 - val_accuracy: 0.6217 - lr: 0.0010
# Epoch 8/30
# 565/565 [==============================] - 21s 36ms/step - loss: 1.1919 - accuracy: 0.6248 - val_loss: 1.1894 - val_accuracy: 0.6275 - lr: 0.0010
# Epoch 9/30
# 565/565 [==============================] - 21s 37ms/step - loss: 1.1694 - accuracy: 0.6307 - val_loss: 1.1726 - val_accuracy: 0.6322 - lr: 0.0010
# Epoch 10/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.1481 - accuracy: 0.6368 - val_loss: 1.1588 - val_accuracy: 0.6363 - lr: 0.0010
# Epoch 11/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.1292 - accuracy: 0.6421 - val_loss: 1.1472 - val_accuracy: 0.6397 - lr: 0.0010
# Epoch 12/30
# 565/565 [==============================] - 21s 37ms/step - loss: 1.1106 - accuracy: 0.6476 - val_loss: 1.1367 - val_accuracy: 0.6438 - lr: 0.0010
# Epoch 13/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.0940 - accuracy: 0.6525 - val_loss: 1.1292 - val_accuracy: 0.6456 - lr: 0.0010
# Epoch 14/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.0777 - accuracy: 0.6572 - val_loss: 1.1190 - val_accuracy: 0.6487 - lr: 0.0010
# Epoch 15/30
# 565/565 [==============================] - 22s 38ms/step - loss: 1.0632 - accuracy: 0.6617 - val_loss: 1.1151 - val_accuracy: 0.6496 - lr: 0.0010
# Epoch 16/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.0512 - accuracy: 0.6649 - val_loss: 1.1101 - val_accuracy: 0.6510 - lr: 0.0010
# Epoch 17/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.0410 - accuracy: 0.6682 - val_loss: 1.1085 - val_accuracy: 0.6526 - lr: 0.0010
# Epoch 18/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.0312 - accuracy: 0.6711 - val_loss: 1.1025 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 19/30
# 565/565 [==============================] - 22s 37ms/step - loss: 1.0245 - accuracy: 0.6731 - val_loss: 1.1020 - val_accuracy: 0.6540 - lr: 0.0010
# Epoch 20/30
# 565/565 [==============================] - 22s 38ms/step - loss: 1.0187 - accuracy: 0.6748 - val_loss: 1.1004 - val_accuracy: 0.6544 - lr: 0.0010
# Epoch 21/30
# 565/565 [==============================] - 22s 38ms/step - loss: 1.0126 - accuracy: 0.6764 - val_loss: 1.0954 - val_accuracy: 0.6567 - lr: 0.0010
# Epoch 22/30
# 565/565 [==============================] - 22s 38ms/step - loss: 1.0085 - accuracy: 0.6778 - val_loss: 1.0938 - val_accuracy: 0.6567 - lr: 0.0010
# Epoch 23/30
# 565/565 [==============================] - 22s 38ms/step - loss: 1.0065 - accuracy: 0.6780 - val_loss: 1.0997 - val_accuracy: 0.6549 - lr: 0.0010
# Epoch 24/30
# 565/565 [==============================] - 22s 38ms/step - loss: 1.0037 - accuracy: 0.6789 - val_loss: 1.0982 - val_accuracy: 0.6562 - lr: 0.0010
# Epoch 25/30
# 565/565 [==============================] - ETA: 0s - loss: 1.0023 - accuracy: 0.6792
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 565/565 [==============================] - 23s 39ms/step - loss: 1.0023 - accuracy: 0.6792 - val_loss: 1.1012 - val_accuracy: 0.6550 - lr: 0.0010
# Epoch 26/30
# 565/565 [==============================] - 22s 38ms/step - loss: 0.9331 - accuracy: 0.7024 - val_loss: 1.0291 - val_accuracy: 0.6790 - lr: 5.0000e-04
# Epoch 27/30
# 565/565 [==============================] - 22s 37ms/step - loss: 0.8919 - accuracy: 0.7168 - val_loss: 1.0210 - val_accuracy: 0.6821 - lr: 5.0000e-04
# Epoch 28/30
# 565/565 [==============================] - 22s 38ms/step - loss: 0.8721 - accuracy: 0.7229 - val_loss: 1.0157 - val_accuracy: 0.6844 - lr: 5.0000e-04
# Epoch 29/30
# 565/565 [==============================] - 22s 38ms/step - loss: 0.8592 - accuracy: 0.7273 - val_loss: 1.0090 - val_accuracy: 0.6867 - lr: 5.0000e-04
# Epoch 30/30
# 565/565 [==============================] - 22s 38ms/step - loss: 0.8470 - accuracy: 0.7313 - val_loss: 1.0062 - val_accuracy: 0.6876 - lr: 5.0000e-04

# %%
# Default value of epochs wasn't used here
lstm_model.compile(optimizer=lstm_model.optimizer, loss=lstm_model.loss,metrics=lstm_model.metric)
lstm_model.fit(train_dataset, epochs=50, validation_data=val_dataset, callbacks=lstm_model.callbacks)
lstm_history = lstm_model.history
plot(lstm_history)
# Out:
# Epoch 1/50
# 565/565 [==============================] - 27s 44ms/step - loss: 2.2708 - accuracy: 0.3604 - val_loss: 1.7903 - val_accuracy: 0.4700 - lr: 0.0010
# Epoch 2/50
# 565/565 [==============================] - 26s 44ms/step - loss: 1.6250 - accuracy: 0.5136 - val_loss: 1.5050 - val_accuracy: 0.5468 - lr: 0.0010
# Epoch 3/50
# 565/565 [==============================] - 26s 44ms/step - loss: 1.4416 - accuracy: 0.5614 - val_loss: 1.3987 - val_accuracy: 0.5731 - lr: 0.0010
# Epoch 4/50
# 565/565 [==============================] - 26s 45ms/step - loss: 1.3619 - accuracy: 0.5810 - val_loss: 1.3389 - val_accuracy: 0.5876 - lr: 0.0010
# Epoch 5/50
# 565/565 [==============================] - 26s 45ms/step - loss: 1.3145 - accuracy: 0.5927 - val_loss: 1.3058 - val_accuracy: 0.5960 - lr: 0.0010
# Epoch 6/50
# 565/565 [==============================] - 26s 45ms/step - loss: 1.2818 - accuracy: 0.6007 - val_loss: 1.2705 - val_accuracy: 0.6055 - lr: 0.0010
# Epoch 7/50
# 565/565 [==============================] - 26s 45ms/step - loss: 1.2550 - accuracy: 0.6077 - val_loss: 1.2461 - val_accuracy: 0.6117 - lr: 0.0010
# Epoch 8/50
# 565/565 [==============================] - 26s 46ms/step - loss: 1.2331 - accuracy: 0.6131 - val_loss: 1.2294 - val_accuracy: 0.6160 - lr: 0.0010
# Epoch 9/50
# 565/565 [==============================] - 26s 45ms/step - loss: 1.2122 - accuracy: 0.6186 - val_loss: 1.2117 - val_accuracy: 0.6207 - lr: 0.0010
# Epoch 10/50
# 565/565 [==============================] - 26s 46ms/step - loss: 1.1927 - accuracy: 0.6241 - val_loss: 1.1950 - val_accuracy: 0.6248 - lr: 0.0010
# Epoch 11/50
# 565/565 [==============================] - 27s 46ms/step - loss: 1.1744 - accuracy: 0.6290 - val_loss: 1.1806 - val_accuracy: 0.6292 - lr: 0.0010
# Epoch 12/50
# 565/565 [==============================] - 27s 46ms/step - loss: 1.1554 - accuracy: 0.6343 - val_loss: 1.1647 - val_accuracy: 0.6337 - lr: 0.0010
# Epoch 13/50
# 565/565 [==============================] - 27s 46ms/step - loss: 1.1370 - accuracy: 0.6398 - val_loss: 1.1544 - val_accuracy: 0.6367 - lr: 0.0010
# Epoch 14/50
# 565/565 [==============================] - 27s 46ms/step - loss: 1.1199 - accuracy: 0.6448 - val_loss: 1.1445 - val_accuracy: 0.6398 - lr: 0.0010
# Epoch 15/50
# 565/565 [==============================] - 27s 47ms/step - loss: 1.1009 - accuracy: 0.6504 - val_loss: 1.1294 - val_accuracy: 0.6439 - lr: 0.0010
# Epoch 16/50
# 565/565 [==============================] - 27s 46ms/step - loss: 1.0827 - accuracy: 0.6559 - val_loss: 1.1199 - val_accuracy: 0.6469 - lr: 0.0010
# Epoch 17/50
# 565/565 [==============================] - 27s 46ms/step - loss: 1.0650 - accuracy: 0.6613 - val_loss: 1.1097 - val_accuracy: 0.6505 - lr: 0.0010
# Epoch 18/50
# 565/565 [==============================] - 27s 46ms/step - loss: 1.0471 - accuracy: 0.6667 - val_loss: 1.0961 - val_accuracy: 0.6549 - lr: 0.0010
# Epoch 19/50
# 565/565 [==============================] - 40s 70ms/step - loss: 1.0298 - accuracy: 0.6724 - val_loss: 1.0870 - val_accuracy: 0.6580 - lr: 0.0010
# Epoch 20/50
# 565/565 [==============================] - 56s 98ms/step - loss: 1.0117 - accuracy: 0.6779 - val_loss: 1.0786 - val_accuracy: 0.6608 - lr: 0.0010
# Epoch 21/50
# 565/565 [==============================] - 55s 96ms/step - loss: 0.9955 - accuracy: 0.6831 - val_loss: 1.0716 - val_accuracy: 0.6630 - lr: 0.0010
# Epoch 22/50
# 565/565 [==============================] - 54s 95ms/step - loss: 0.9790 - accuracy: 0.6885 - val_loss: 1.0654 - val_accuracy: 0.6652 - lr: 0.0010
# Epoch 23/50
# 565/565 [==============================] - 54s 94ms/step - loss: 0.9630 - accuracy: 0.6935 - val_loss: 1.0588 - val_accuracy: 0.6677 - lr: 0.0010
# Epoch 24/50
# 565/565 [==============================] - 54s 94ms/step - loss: 0.9479 - accuracy: 0.6986 - val_loss: 1.0483 - val_accuracy: 0.6717 - lr: 0.0010
# Epoch 25/50
# 565/565 [==============================] - 54s 94ms/step - loss: 0.9329 - accuracy: 0.7032 - val_loss: 1.0450 - val_accuracy: 0.6730 - lr: 0.0010
# Epoch 26/50
# 565/565 [==============================] - 54s 95ms/step - loss: 0.9211 - accuracy: 0.7072 - val_loss: 1.0403 - val_accuracy: 0.6744 - lr: 0.0010
# Epoch 27/50
# 565/565 [==============================] - 54s 94ms/step - loss: 0.9085 - accuracy: 0.7112 - val_loss: 1.0358 - val_accuracy: 0.6762 - lr: 0.0010
# Epoch 28/50
# 565/565 [==============================] - 54s 94ms/step - loss: 0.8961 - accuracy: 0.7153 - val_loss: 1.0317 - val_accuracy: 0.6778 - lr: 0.0010
# Epoch 29/50
# 565/565 [==============================] - 53s 94ms/step - loss: 0.8861 - accuracy: 0.7182 - val_loss: 1.0238 - val_accuracy: 0.6808 - lr: 0.0010
# Epoch 30/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8752 - accuracy: 0.7215 - val_loss: 1.0214 - val_accuracy: 0.6821 - lr: 0.0010
# Epoch 31/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8659 - accuracy: 0.7244 - val_loss: 1.0174 - val_accuracy: 0.6832 - lr: 0.0010
# Epoch 32/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8583 - accuracy: 0.7270 - val_loss: 1.0154 - val_accuracy: 0.6845 - lr: 0.0010
# Epoch 33/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8494 - accuracy: 0.7296 - val_loss: 1.0126 - val_accuracy: 0.6852 - lr: 0.0010
# Epoch 34/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8420 - accuracy: 0.7320 - val_loss: 1.0140 - val_accuracy: 0.6853 - lr: 0.0010
# Epoch 35/50
# 565/565 [==============================] - 54s 94ms/step - loss: 0.8355 - accuracy: 0.7338 - val_loss: 1.0083 - val_accuracy: 0.6868 - lr: 0.0010
# Epoch 36/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8291 - accuracy: 0.7359 - val_loss: 1.0043 - val_accuracy: 0.6888 - lr: 0.0010
# Epoch 37/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8235 - accuracy: 0.7377 - val_loss: 1.0048 - val_accuracy: 0.6885 - lr: 0.0010
# Epoch 38/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8192 - accuracy: 0.7388 - val_loss: 1.0004 - val_accuracy: 0.6906 - lr: 0.0010
# Epoch 39/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8143 - accuracy: 0.7402 - val_loss: 1.0012 - val_accuracy: 0.6907 - lr: 0.0010
# Epoch 40/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8097 - accuracy: 0.7416 - val_loss: 1.0038 - val_accuracy: 0.6898 - lr: 0.0010
# Epoch 41/50
# 565/565 [==============================] - ETA: 0s - loss: 0.8071 - accuracy: 0.7422
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 565/565 [==============================] - 53s 93ms/step - loss: 0.8071 - accuracy: 0.7422 - val_loss: 1.0039 - val_accuracy: 0.6893 - lr: 0.0010
# Epoch 42/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.7352 - accuracy: 0.7696 - val_loss: 0.9286 - val_accuracy: 0.7168 - lr: 5.0000e-04
# Epoch 43/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6939 - accuracy: 0.7856 - val_loss: 0.9209 - val_accuracy: 0.7205 - lr: 5.0000e-04
# Epoch 44/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6774 - accuracy: 0.7913 - val_loss: 0.9131 - val_accuracy: 0.7236 - lr: 5.0000e-04
# Epoch 45/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6660 - accuracy: 0.7954 - val_loss: 0.9123 - val_accuracy: 0.7244 - lr: 5.0000e-04
# Epoch 46/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6565 - accuracy: 0.7983 - val_loss: 0.9090 - val_accuracy: 0.7258 - lr: 5.0000e-04
# Epoch 47/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6491 - accuracy: 0.8005 - val_loss: 0.9093 - val_accuracy: 0.7264 - lr: 5.0000e-04
# Epoch 48/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6398 - accuracy: 0.8035 - val_loss: 0.9049 - val_accuracy: 0.7284 - lr: 5.0000e-04
# Epoch 49/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6321 - accuracy: 0.8058 - val_loss: 0.9019 - val_accuracy: 0.7297 - lr: 5.0000e-04
# Epoch 50/50
# 565/565 [==============================] - 53s 93ms/step - loss: 0.6249 - accuracy: 0.8083 - val_loss: 0.8973 - val_accuracy: 0.7315 - lr: 5.0000e-04

# %%
rnn_model.compile(optimizer=rnn_model.optimizer, loss=rnn_model.loss,metrics=rnn_model.metric)
rnn_model.fit(train_dataset, epochs=rnn_model.epochs, validation_data=val_dataset, callbacks=rnn_model.callbacks)
rnn_history = rnn_model.history
plot(rnn_history)
# Out:
# Epoch 1/30
# 565/565 [==============================] - 40s 66ms/step - loss: 2.2540 - accuracy: 0.3660 - val_loss: 1.8401 - val_accuracy: 0.4608 - lr: 0.0010
# Epoch 2/30
# 565/565 [==============================] - 38s 66ms/step - loss: 1.7004 - accuracy: 0.4954 - val_loss: 1.5944 - val_accuracy: 0.5240 - lr: 0.0010
# Epoch 3/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.5405 - accuracy: 0.5365 - val_loss: 1.4969 - val_accuracy: 0.5482 - lr: 0.0010
# Epoch 4/30
# 565/565 [==============================] - 38s 66ms/step - loss: 1.4653 - accuracy: 0.5546 - val_loss: 1.4468 - val_accuracy: 0.5601 - lr: 0.0010
# Epoch 5/30
# 565/565 [==============================] - 38s 66ms/step - loss: 1.4231 - accuracy: 0.5646 - val_loss: 1.4150 - val_accuracy: 0.5678 - lr: 0.0010
# Epoch 6/30
# 565/565 [==============================] - 39s 67ms/step - loss: 1.3950 - accuracy: 0.5715 - val_loss: 1.3908 - val_accuracy: 0.5721 - lr: 0.0010
# Epoch 7/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.3745 - accuracy: 0.5758 - val_loss: 1.3729 - val_accuracy: 0.5770 - lr: 0.0010
# Epoch 8/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.3581 - accuracy: 0.5798 - val_loss: 1.3623 - val_accuracy: 0.5801 - lr: 0.0010
# Epoch 9/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.3451 - accuracy: 0.5830 - val_loss: 1.3536 - val_accuracy: 0.5813 - lr: 0.0010
# Epoch 10/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.3340 - accuracy: 0.5857 - val_loss: 1.3460 - val_accuracy: 0.5845 - lr: 0.0010
# Epoch 11/30
# 565/565 [==============================] - 40s 69ms/step - loss: 1.3257 - accuracy: 0.5877 - val_loss: 1.3365 - val_accuracy: 0.5857 - lr: 0.0010
# Epoch 12/30
# 565/565 [==============================] - 39s 69ms/step - loss: 1.3180 - accuracy: 0.5895 - val_loss: 1.3308 - val_accuracy: 0.5872 - lr: 0.0010
# Epoch 13/30
# 565/565 [==============================] - 40s 70ms/step - loss: 1.3114 - accuracy: 0.5913 - val_loss: 1.3192 - val_accuracy: 0.5903 - lr: 0.0010
# Epoch 14/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.3081 - accuracy: 0.5922 - val_loss: 1.3196 - val_accuracy: 0.5904 - lr: 0.0010
# Epoch 15/30
# 565/565 [==============================] - 40s 69ms/step - loss: 1.2999 - accuracy: 0.5942 - val_loss: 1.3127 - val_accuracy: 0.5917 - lr: 0.0010
# Epoch 16/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.2947 - accuracy: 0.5956 - val_loss: 1.3090 - val_accuracy: 0.5937 - lr: 0.0010
# Epoch 17/30
# 565/565 [==============================] - 39s 67ms/step - loss: 1.2911 - accuracy: 0.5962 - val_loss: 1.3074 - val_accuracy: 0.5937 - lr: 0.0010
# Epoch 18/30
# 565/565 [==============================] - 41s 71ms/step - loss: 1.2865 - accuracy: 0.5971 - val_loss: 1.3019 - val_accuracy: 0.5950 - lr: 0.0010
# Epoch 19/30
# 565/565 [==============================] - 41s 72ms/step - loss: 1.2820 - accuracy: 0.5984 - val_loss: 1.3046 - val_accuracy: 0.5954 - lr: 0.0010
# Epoch 20/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.2786 - accuracy: 0.5992 - val_loss: 1.2953 - val_accuracy: 0.5969 - lr: 0.0010
# Epoch 21/30
# 565/565 [==============================] - 39s 68ms/step - loss: 1.2750 - accuracy: 0.6000 - val_loss: 1.2930 - val_accuracy: 0.5966 - lr: 0.0010
# Epoch 22/30
# 565/565 [==============================] - 40s 69ms/step - loss: 1.2729 - accuracy: 0.6006 - val_loss: 1.2912 - val_accuracy: 0.5973 - lr: 0.0010
# Epoch 23/30
# 565/565 [==============================] - 47s 81ms/step - loss: 1.2697 - accuracy: 0.6014 - val_loss: 1.2895 - val_accuracy: 0.5984 - lr: 0.0010
# Epoch 24/30
# 565/565 [==============================] - 47s 83ms/step - loss: 1.2671 - accuracy: 0.6021 - val_loss: 1.2907 - val_accuracy: 0.5971 - lr: 0.0010
# Epoch 25/30
# 565/565 [==============================] - 42s 74ms/step - loss: 1.2649 - accuracy: 0.6027 - val_loss: 1.2937 - val_accuracy: 0.5964 - lr: 0.0010
# Epoch 26/30
# 565/565 [==============================] - 42s 73ms/step - loss: 1.2632 - accuracy: 0.6032 - val_loss: 1.2868 - val_accuracy: 0.5990 - lr: 0.0010
# Epoch 27/30
# 565/565 [==============================] - 42s 74ms/step - loss: 1.2610 - accuracy: 0.6037 - val_loss: 1.2903 - val_accuracy: 0.5971 - lr: 0.0010
# Epoch 28/30
# 565/565 [==============================] - 42s 74ms/step - loss: 1.2596 - accuracy: 0.6039 - val_loss: 1.2924 - val_accuracy: 0.5974 - lr: 0.0010
# Epoch 29/30
# 565/565 [==============================] - 43s 75ms/step - loss: 1.2579 - accuracy: 0.6045 - val_loss: 1.2843 - val_accuracy: 0.5989 - lr: 0.0010
# Epoch 30/30
# 565/565 [==============================] - 42s 72ms/step - loss: 1.2569 - accuracy: 0.6047 - val_loss: 1.2834 - val_accuracy: 0.5993 - lr: 0.0010

# %%
gru_model.save_weights('gru_weights.h5')
lstm_model.save_weights('lstm_weights.h5')
rnn_model.save_weights('rnn_weights.h5')

# %%
gru_model.load_weights('gru_weights.h5')
lstm_model.load_weights('lstm_weights.h5')
rnn_model.load_weights('rnn_weights.h5')

# %% [markdown]
# ## 7. TESTING THE TRAINED MODEL

# %%
gru_out = OneStep(gru_model, chars_from_id, tokenizer)
lstm_out = OneStep(lstm_model, chars_from_id, tokenizer)
rnn_out = OneStep(rnn_model, chars_from_id, tokenizer)

# %%
start = time.time()
states = None
next_char = tf.constant(['All: \n thou heart stinks thee'])
result = [next_char]

for n in range(1000):
    next_char, states = gru_out.generate_one_step(next_char, states=states)
    result.append(next_char)

result = tf.strings.join(result)
end = time.time()
print(result[0].numpy().decode('utf-8'), '\n\n' + '_'*80)
print('\nRun time:', end - start)
# Out:
# All:
#  thou heart stinks thee he hath much poor labour of
# the difference. Then this is not yet wherein negligence,
# I would appear against ambassador than I,
# And when I am afeard
# I did home sack: Say the untertaken's
# remains without me: she never came full of heart:
# Joinn is all wither'd in these faults that does not die:
# Laid Thisby shall do wear his daughter.
#
# LYSANDER:
# 'Tis a shadow of his dog, adieu:'--
#
# RUGLEO:
# For me, take down me.
#
# MENAS:
# We'll plead you so, and let me find Master Plagus; let us he
# There stay your blinds that I can of the new.
# Good as there is my present bed and place
# With cheer. Now, Bratsmell, that contains
# Comes not the Daneagent frost-spring to the shift?
# Then let thy brother Titus Lary Peter,
# And little have chrosp'd up with Halfurious neck,
# Than in these dangerous eyes to their enemies.
# Adoin!
# O Montry, from cymech and weeds now
# made me an ass! How might when such master's beauty would
# desight to see?
#
# CADE:
# O, a most pin he took a strange redemption moderate,
# for perespions, take thos
#
# ________________________________________________________________________________
#
# Run time: 9.283502578735352

# %%
start = time.time()
states = None
next_char = tf.constant(['All: \n thou heart stinks thee'])
result = [next_char]

for n in range(1000):
    next_char, states = lstm_out.generate_one_step(next_char, states=states)
    result.append(next_char)

result = tf.strings.join(result)
end = time.time()
print(result[0].numpy().decode('utf-8'), '\n\n' + '_'*80)
print('\nRun time:', end - start)
# Out:
# All:
#  thou heart stinks thee from thy state in thy name
# well: that same lion is oped made of, so they
# such a murderous vowering nor why, they shall not be made
# me at my death to the desire. And she is allowed but by
# the face of my that wants utmers, after them i'
# the two king.
#
# Poet:
# Then thou hadst little from me threach so many
# a mass, as any matter, happily entreats them.
# His Desdemona should be most understanding
# by the princely grandsire? I have sing in thy knife,
# with such-like you are to you and other exhaletes
# than a motley throat. I lead this place with a word.
#
# AUDREY:
# It is a happiness, O noble blost, in fine
# A royal officer court: choich and drink, shotter,--
# I was too near my people.
#
# CORIOLANUS:
# Truly, sister, when our Cymberk shall underveatle.
#
# SUFFOLK:
# I'll talk them forth: since thou hast need, thou shalt
# ne'er pass on thy breast in secret,--at and by:
# I know 'tis boots thee for thy father's hat.
# Come buy! why, both a parle excuse of me,
# Though well becomes thee better than my foe?
#
# YORK:
# Speak,
#
# ________________________________________________________________________________
#
# Run time: 7.073847770690918

# %%
start = time.time()
states = None
next_char = tf.constant(['All: \n thou heart stinks thee'])
result = [next_char]

for n in range(1000):
    next_char, states = rnn_out.generate_one_step(next_char, states=states)
    result.append(next_char)

result = tf.strings.join(result)
end = time.time()
print(result[0].numpy().decode('utf-8'), '\n\n' + '_'*80)
print('\nRun time:', end - start)
# Out:
# All:
#  thou heart stinks thee to point.
#
# OPHELIA:
# What token:
# Mine tapor shall obey well.
#
# GLOUCESTER:
# Was a dog?
#
# HUBENT:
# Worked I will give thee short,
# And I must to the march,
# Whose spirits from her pass,
# Waking, as fall'n body?
# 'Tis he i' the noble brave thing
# These that to-day, as much
# past, the mighty host,
# Contemplance action of an
# ass of heaven, the stamp of our extremes, till let Of wit to service to captain, makes me straited and true return'd,
# As he is mock
# Troe no goes
# Shall wear it.
#
# FLAMEOT:
# Were his life, or else you made well
# To thyself and good Harry; oaths of the world;
# The prince upon my
# faith,
# to the babilings: there's a pretty: I see no law and Caesar,
# As unknown thus,
# He both shine.
#
# HOLETH:
# So, sir, get you gone!
# Jool, let our friendshipes,
# I'll sound at weary.
#
# Sexton:
# Sweet, watch'd to be here and
# chaste yield again;
# How hear'st since you know thy life, who would not be unkind-merchant,
# But up and hazard our bends with caitiff: and that he will do contend.
#
# KING HENRY V:
# I'll seal her?
# Pa
#
# ________________________________________________________________________________
#
# Run time: 4.234472274780273

# %% [markdown]
# ## 8. WORD LEVEL SCRIPT

# %%
from my_rnns import word_level_process_data,data_set_word_level

# %% [markdown]
# ## Considering a small part of the text

# %%
word_level_text = text[:50000]
word_level_text = word_level_text.lower().split("\n")

# %% [markdown]
# ## 8.1 TOKENIZING

# %%
word_lvl_obj = word_level_process_data(word_level_text)
tokenizer = word_lvl_obj.word_level_process()
# Out:
#  The total words are :2081
#
#
# Do u want to print the word dictionary? (y/n)
#
# y
#
#
# The word index dictionary is :
#
#  {'the': 1, 'and': 2, 'to': 3, 'you': 4, 'i': 5, 'of': 6, 'a': 7, 'in': 8, 'that': 9, 'he': 10, 'marcius': 11, 'not': 12, 'for': 13, 'your': 14, 'him': 15, 'it': 16, 'with': 17, 'my': 18, 'is': 19, 'have': 20, 'as': 21, 'be': 22, 'they': 23, 'we': 24, 'his': 25, 'are': 26, 'their': 27, 'first': 28, 'our': 29, 'but': 30, 'menenius': 31, 'me': 32, 'all': 33, 'what': 34, 'good': 35, 'shall': 36, 'this': 37, 'will': 38, 'than': 39, 'if': 40, 'no': 41, 'at': 42, 'us': 43, 'cominius': 44, 'them': 45, 'well': 46, 'so': 47, 'do': 48, 'citizen': 49, 'more': 50, 'would': 51, 'which': 52, 'make': 53, 'aufidius': 54, 'on': 55, 'or': 56, 'brutus': 57, 'volumnia': 58, 'were': 59, 'come': 60, 'by': 61, 'know': 62, 'where': 63, 'upon': 64, 'lartius': 65, 'one': 66, 'like': 67, 'from': 68, 'then': 69, 'rome': 70, "'tis": 71, 'was': 72, 'when': 73, 'how': 74, 'o': 75, 'must': 76, 'sicinius': 77, 'an': 78, 'sir': 79, 'thou': 80, 'nor': 81, 'virgilia': 82, 'coriolanus': 83, 'go': 84, 'yet': 85, 'did': 86, 'these': 87, 'who': 88, 'had': 89, 'now': 90, 'see': 91, 'thy': 92, 'let': 93, 'hath': 94, 'here': 95, 'say': 96, "o'": 97, 'should': 98, 'out': 99, 'valeria': 100, 'people': 101, 'second': 102, 'gods': 103, 'most': 104, "i'll": 105, 'too': 106, 'give': 107, 'am': 108, 'speak': 109, 'think': 110, 'against': 111, 'though': 112, 'can': 113, 'true': 114, 'love': 115, 'soldier': 116, 'hear': 117, 'very': 118, 'proud': 119, 'city': 120, 'may': 121, 'time': 122, "i'": 123, 'such': 124, 'man': 125, 'her': 126, 'noble': 127, 'thee': 128, 'forth': 129, 'home': 130, 'senator': 131, 'titus': 132, 'before': 133, 'caius': 134, 'done': 135, 'has': 136, 'men': 137, 'tell': 138, 'up': 139, 'only': 140, 'made': 141, 'great': 142, 'some': 143, 'alone': 144, 'corioli': 145, 'madam': 146, 'she': 147, 'report': 148, 'being': 149, 'friends': 150, 'ever': 151, 'indeed': 152, 'bear': 153, 'there': 154, 'thus': 155, 'general': 156, 'blood': 157, 'hate': 158, 'take': 159, 'those': 160, 'any': 161, 'rather': 162, 'poor': 163, "he's": 164, 'could': 165, 'cannot': 166, 'why': 167, 'pray': 168, 'roman': 169, 'little': 170, 'belly': 171, 'heart': 172, 'power': 173, 'honours': 174, 'way': 175, 'capitol': 176, 'worthy': 177, 'matter': 178, 'wars': 179, "there's": 180, 'call': 181, 'messenger': 182, 'volsces': 183, 'fight': 184, "that's": 185, 'welcome': 186, 'both': 187, 'own': 188, 'ere': 189, 'nay': 190, 'even': 191, 'other': 192, 'mine': 193, 'heard': 194, 'common': 195, 'answer': 196, 'look': 197, "'": 198, 'leave': 199, 'find': 200, 'stand': 201, 'sword': 202, 'news': 203, 'best': 204, 'wish': 205, 'fought': 206, 'half': 207, 'been': 208, 'known': 209, 'many': 210, 'set': 211, 'son': 212, 'honour': 213, 'thank': 214, 'officer': 215, 'word': 216, 'country': 217, 'enough': 218, 'care': 219, 'off': 220, 'body': 221, 'never': 222, 'grave': 223, 'ay': 224, "what's": 225, 'down': 226, 'every': 227, 'put': 228, 'much': 229, 'eyes': 230, 'better': 231, 'three': 232, 'doubt': 233, 'hour': 234, 'lord': 235, 'again': 236, 'work': 237, 'hearts': 238, "we'll": 239, 'away': 240, 'become': 241, 'himself': 242, 'mother': 243, 'till': 244, 'comes': 245, 'business': 246, 'arms': 247, 'yourselves': 248, 'thither': 249, 'since': 250, "'t": 251, 'patience': 252, 'war': 253, 'hang': 254, 'keep': 255, 'another': 256, 'walls': 257, 'thing': 258, 'world': 259, 'whom': 260, "let's": 261, 'action': 262, 'letter': 263, 'yes': 264, 'whether': 265, 'field': 266, 'farewell': 267, 'wherein': 268, 'lady': 269, 'fear': 270, 'beat': 271, 'ladies': 272, 'does': 273, 'after': 274, 'warrant': 275, 'lie': 276, 'within': 277, 'gates': 278, 'cause': 279, 'two': 280, 'wounded': 281, 'die': 282, 'enemy': 283, 'corn': 284, 'patricians': 285, 'end': 286, 'please': 287, 'help': 288, 'side': 289, 'loved': 290, 'rest': 291, 'hand': 292, 'senate': 293, 'show': 294, "'em": 295, 'strong': 296, 'state': 297, 'appear': 298, "ne'er": 299, 'wondrous': 300, 'purpose': 301, 'steed': 302, "you'll": 303, 'receive': 304, 'house': 3 ...

# %% [markdown]
# ## 8.2 DATASET PREPARATION

# %%
data_word_level_obj = data_set_word_level(word_level_text,tokenizer)
X , Y , max_seq_length = data_word_level_obj.gen_data()

# %% [markdown]
# ## 8.3 BI-DIRECTIONAL LSTM FOR WORD PREDICTION
#
# ### MODEL UTILIZES ALL 3 CALLBACKS

# %%
callbacks=[
            tf.keras.callbacks.ModelCheckpoint(filepath='bi_direc_lstm.h5',
                                                monitor='accuracy', 
                                                save_best_only=True, 
                                                mode='max', 
                                                verbose=1),
            tf.keras.callbacks.EarlyStopping(monitor='loss',
                                             mode='auto',
                                             verbose=1,
                                             patience=3),
            tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', 
                                                patience=3,
                                                verbose=1,
                                                factor=.5, 
                                                min_lr=0.0000001)
        ]

embedding_dim = 256
lstm_units = 150
learning_rate = 0.01
epochs = 50


model = tf.keras.models.Sequential([
          tf.keras.layers.Embedding(len(tokenizer.word_index)+1, embedding_dim, input_length=max_seq_length-1),
          tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm_units)),
          tf.keras.layers.Dense(len(tokenizer.word_index)+1, activation='softmax')
])


model.compile(
    loss='categorical_crossentropy', 
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), 
    metrics=['accuracy']
    )


model.summary()


history = model.fit(X, Y, epochs=epochs , callbacks=callbacks)

plt.figure()
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.xlabel("Epochs")
plt.ylabel('accuracy')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.xlabel("Epochs")
plt.ylabel('loss')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 11, 256)           532736
#
#  bidirectional_4 (Bidirectio  (None, 300)              488400
#  nal)
#
#  dense_4 (Dense)             (None, 2081)              626381
#
# =================================================================
# Total params: 1,647,517
# Trainable params: 1,647,517
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 234/235 [============================>.] - ETA: 0s - loss: 6.6643 - accuracy: 0.0433
# Epoch 1: accuracy improved from -inf to 0.04326, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 12s 27ms/step - loss: 6.6641 - accuracy: 0.0433 - lr: 0.0100
# Epoch 2/50
# 234/235 [============================>.] - ETA: 0s - loss: 5.8524 - accuracy: 0.0676
# Epoch 2: accuracy improved from 0.04326 to 0.06770, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 33ms/step - loss: 5.8518 - accuracy: 0.0677 - lr: 0.0100
# Epoch 3/50
# 234/235 [============================>.] - ETA: 0s - loss: 5.1023 - accuracy: 0.1095
# Epoch 3: accuracy improved from 0.06770 to 0.10949, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 7s 29ms/step - loss: 5.1023 - accuracy: 0.1095 - lr: 0.0100
# Epoch 4/50
# 235/235 [==============================] - ETA: 0s - loss: 4.2047 - accuracy: 0.1776
# Epoch 4: accuracy improved from 0.10949 to 0.17759, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 7s 32ms/step - loss: 4.2047 - accuracy: 0.1776 - lr: 0.0100
# Epoch 5/50
# 234/235 [============================>.] - ETA: 0s - loss: 3.4294 - accuracy: 0.2683
# Epoch 5: accuracy improved from 0.17759 to 0.26826, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 6s 26ms/step - loss: 3.4294 - accuracy: 0.2683 - lr: 0.0100
# Epoch 6/50
# 234/235 [============================>.] - ETA: 0s - loss: 2.6214 - accuracy: 0.3953
# Epoch 6: accuracy improved from 0.26826 to 0.39525, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 33ms/step - loss: 2.6218 - accuracy: 0.3952 - lr: 0.0100
# Epoch 7/50
# 234/235 [============================>.] - ETA: 0s - loss: 2.0136 - accuracy: 0.5106
# Epoch 7: accuracy improved from 0.39525 to 0.51062, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 35ms/step - loss: 2.0135 - accuracy: 0.5106 - lr: 0.0100
# Epoch 8/50
# 234/235 [============================>.] - ETA: 0s - loss: 1.6294 - accuracy: 0.6018
# Epoch 8: accuracy improved from 0.51062 to 0.60182, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 34ms/step - loss: 1.6294 - accuracy: 0.6018 - lr: 0.0100
# Epoch 9/50
# 235/235 [==============================] - ETA: 0s - loss: 1.3441 - accuracy: 0.6702
# Epoch 9: accuracy improved from 0.60182 to 0.67018, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 34ms/step - loss: 1.3441 - accuracy: 0.6702 - lr: 0.0100
# Epoch 10/50
# 235/235 [==============================] - ETA: 0s - loss: 1.1877 - accuracy: 0.7038
# Epoch 10: accuracy improved from 0.67018 to 0.70383, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 34ms/step - loss: 1.1877 - accuracy: 0.7038 - lr: 0.0100
# Epoch 11/50
# 235/235 [==============================] - ETA: 0s - loss: 1.0454 - accuracy: 0.7353
# Epoch 11: accuracy improved from 0.70383 to 0.73535, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 34ms/step - loss: 1.0454 - accuracy: 0.7353 - lr: 0.0100
# Epoch 12/50
# 235/235 [==============================] - ETA: 0s - loss: 0.9627 - accuracy: 0.7610
# Epoch 12: accuracy improved from 0.73535 to 0.76098, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 33ms/step - loss: 0.9627 - accuracy: 0.7610 - lr: 0.0100
# Epoch 13/50
# 235/235 [==============================] - ETA: 0s - loss: 0.8422 - accuracy: 0.7881
# Epoch 13: accuracy improved from 0.76098 to 0.78809, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 34ms/step - loss: 0.8422 - accuracy: 0.7881 - lr: 0.0100
# Epoch 14/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.7468 - accuracy: 0.8136
# Epoch 14: accuracy improved from 0.78809 to 0.81359, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 33ms/step - loss: 0.7467 - accuracy: 0.8136 - lr: 0.0100
# Epoch 15/50
# 235/235 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.8231
# Epoch 15: accuracy improved from 0.81359 to 0.82307, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 33ms/step - loss: 0.6920 - accuracy: 0.8231 - lr: 0.0100
# Epoch 16/50
# 235/235 [==============================] - ETA: 0s - loss: 0.6695 - accuracy: 0.8243
# Epoch 16: accuracy improved from 0.82307 to 0.82428, saving model to bi_direc_lstm.h5
# 235/235 [==============================] - 8s 34ms/step - loss: 0.6695 - accuracy: 0.8243 - lr: 0.0100
# Epoch 17/50
# 235/235 [==============================] - ETA: 0s - loss: 0.6850 - accuracy: 0.8232
# Epoch 17: accuracy did not improve from 0.82428
# 235/235 [==============================] - 8s 33ms/step - loss: 0.6850 - accuracy: 0.8232 - lr: 0.0100
# Epoch 18/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.8112
# Epoch 18: accuracy did not improve from 0.82428
# 235/235 [==============================] - 8s 34ms/step - loss: 0.7105 - accuracy: 0.8112 - lr: 0.0100
# Epoch 19/50
# 235/235 [==============================] - ETA: 0s - loss: 0.8561 - accuracy: 0.7671
# Epoch 19: accuracy did not improve from 0.82428
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 235/235 [==============================] - 8s 34ms/step - loss: 0.8561 - accuracy: 0.7671 - lr: 0.0100
# Epoch 19: early stopping
# Text(0, 0.5, 'loss')

# %% [markdown]
# ## 8.4 PREDICTION USING THE TRAINED MODEL

# %%
model = tf.keras.models.load_model('bi_direc_lstm.h5')

# Define seed text
seed_text = 'So, sir, get you gone!'

# Define total words to predict
next_words = 200

# Loop until desired length is reached
for _ in range(next_words):

        # Convert the seed text to a token sequence
        token_list = tokenizer.texts_to_sequences([seed_text])[0]

        # Pad the sequence
        token_list = tf.keras.preprocessing.sequence.pad_sequences([token_list], maxlen=max_seq_length-1, padding='pre')

        # Feed to the model and get the probabilities for each index
        probabilities = model.predict(token_list, verbose=0)

        # Get the index with the highest probability
        predicted = np.argmax(probabilities, axis=-1)[0]

        # Ignore if index is 0 because that is just the padding.
        if predicted != 0:

            # Look up the word associated with the index. 
            output_word = tokenizer.index_word[predicted]

            # Combine with the seed text
            seed_text += " " + output_word

# Print the result
print(seed_text)
# Out:
# So, sir, get you gone! with one part of your syllables and all but what i think they say there's all resolved rather to die than to do no more their mother and they are price they will they will and they will they think well enough too what barm can your bisson to me and it with me will to they will and you friends him a mine emulation but they will and you well forth he and leaves than to a than they at will for him they say they will i will they were so that if they love they with us humanely they were so the good report should they have been my they love they give him and they think they will and an hour of patience and hate me have an equal force thine as easy they will and and a little of a vulgar station or and fight with t'other fight and run me and you go enough too if him you to't in no way in that say may be you they say there's all the love they brain and your affections are that so may can be they no they they had if they love they

# %% [markdown]
# ## 8.5 ANALYZING WEIGHTS
# ## Analyzed for the bi-directional lstm

# %% [markdown]
# ## 8.5.1 First plot X-axis = the dimension(256 here)  Y-axis = Each word , there are total 2081 words. Each dimension value ranges from -3 to +3

# %%
# Load your RNN model
model = tf.keras.models.load_model('bi_direc_lstm.h5')

# Get the weights of the model's first RNN layer
rnn_layer = model.layers[0]
weights = rnn_layer.get_weights()[0]

# Visualize the weights using a heatmap
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.heatmap(weights, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## 8.5.2 Analyzing weight changes

# %%
# Analyze how the weights change over time during training
for i in range(2):
    model.fit(X, Y, epochs=1, batch_size=32)
    weights = rnn_layer.get_weights()[0]
    plt.plot(weights)    
plt.show()
# Out:
# 235/235 [==============================] - 3s 8ms/step - loss: 0.6689 - accuracy: 0.8310
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6424 - accuracy: 0.8316

# %% [markdown]
# ## 8.5.3 Using PCA for dimesionality reduction and then plotting the 2081 words
# ## Here we are reducing the dimensions from 256 to 2

# %%
# Use PCA to identify patterns in the weights
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
weights_pca = pca.fit_transform(weights)
print(weights_pca.shape)
plt.scatter(weights_pca[:,0], weights_pca[:,1])
plt.show()
# Out:
# (2081, 2)

# %% [markdown]
# ## tensor-board can be used for better visualiazation of clustering of words
